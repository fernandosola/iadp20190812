# %% [markdown]
# # Análise de Gastos com Passagens Aéreas (SCDP)

# %% [markdown]
# ## Informações
# * Origem dos dados
# ```
# Portal da Transparência (http://transparencia.gov.br/download-de-dados/viagens)
# ```
# * Dicionário de dados
# ```
# http://transparencia.gov.br/pagina-interna/603364-dicion%C3%A1rio-de-dados-viagens-a-Servi%C3%A7o-Pagamentos
# ```
# * 4 arquivos:
#     * 2018_Pagamento.csv
#     * 2018_Passagem.csv
#     * 2018_Trecho.csv
#     * 2018_Viagem.csv

# %% [markdown]
# ## Perguntas a serem respondidas?
#
# * Qual o trecho mais executado?
# * Qual o valor médio para o trecho mais executado?
# * Qual a mediana para o trecho mais executado?
# * Identificar possíveis outliers nos valores do trecho mais executado

# %%
import pandas as pd
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', 200)
pd.set_option('display.float_format', lambda x: '{:.2f}'.format(x))

plt.rcParams['figure.dpi'] = 90

# %% [markdown]
# # Leitura dos Dados
# ---

# %%
"""
Leia o arquivo
'dados/c04_passagens/2018_Passagem.csv.zip'
"""
df_passagens = pd.read_csv('dados/c04_passagens/2018_Passagem.csv.zip', encoding='latin1', sep=';')

# %% [markdown]
# # Identificação de valores nulos ou faltantes
# ---

# %%
df_passagens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310816 entries, 0 to 310815
# Data columns (total 16 columns):
# Identificador do processo de viagem    310816 non-null int64
# Meio de transporte                     310816 non-null object
# País - Origem ida                      310816 non-null object
# UF - Origem ida                        303560 non-null object
# Cidade - Origem ida                    310816 non-null object
# País - Destino ida                     310816 non-null object
# UF - Destino ida                       301096 non-null object
# Cidade - Destino ida                   310816 non-null object
# País - Origem volta                    310816 non-null object
# UF - Origem volta                      307823 non-null object
# Cidade - Origem volta                  310816 non-null object
# Pais - Destino volta                   310816 non-null object
# UF - Destino volta                     310234 non-null object
# Cidade - Destino volta                 310816 non-null object
# Valor da passagem                      310816 non-null object
# Taxa de serviço                        310816 non-null object
# dtypes: int64(1), object(15)
# memory usage: 37.9+ MB

# %%
df_passagens.sample(10)
# Out:
#         Identificador do processo de viagem Meio de transporte  \
# 112150                             14836547              Aéreo
# 55729                              14718009              Aéreo
# 93868                              14796622              Aéreo
# 306569                             15374510              Aéreo
# 84930                              14778244              Aéreo
# 69881                              14747421              Aéreo
# 251168                             15159695              Aéreo
# 60320                              14728044              Aéreo
# 231721                             15101530              Aéreo
# 71                                 14352354              Aéreo
#
#        País - Origem ida   UF - Origem ida Cidade - Origem ida  \
# 112150            Brasil  Distrito Federal            Brasília
# 55729             Brasil         São Paulo           São Paulo
# 93868             Brasil             Goiás             Goiânia
# 306569            Brasil      Minas Gerais             Uberaba
# 84930             Brasil      Minas Gerais      Belo Horizonte
# 69881             Brasil    Rio de Janeiro      Rio de Janeiro
# 251168            Brasil    Rio de Janeiro      Rio de Janeiro
# 60320             Brasil           Alagoas              Maceió
# 231721            Brasil  Distrito Federal            Brasília
# 71              Alemanha               NaN          Düsseldorf
#
#        País - Destino ida  UF - Destino ida Cidade - Destino ida  \
# 112150             Brasil         São Paulo             Campinas
# 55729              Brasil  Distrito Federal             Brasília
# 93868              Brasil    Rio de Janeiro       Rio de Janeiro
# 306569             Brasil      Minas Gerais       Belo Horizonte
# 84930              Brasil    Rio de Janeiro       Rio de Janeiro
# 69881              Brasil  Distrito Federal             Brasília
# 251168             Brasil  Distrito Federal             Brasília
# 60320              Brasil    Rio de Janeiro       Rio de Janeiro
# 231721             Brasil         Tocantins               Palmas
# 71                 Brasil  Distrito Federal             Brasília
#
#        País - Origem volta UF - Origem volta Cidade - Origem volta  \
# 112150      Sem Informação    Sem Informação        Sem Informação
# 55729       Sem Informação    Sem Informação        Sem Informação
# 93868       Sem Informação    Sem Informação        Sem Informação
# 306569      Sem Informação    Sem Informação        Sem Informação
# 84930       Sem Informação    Sem Informação        Sem Informação
# 69881       Sem Informação    Sem Informação        Sem Informação
# 251168      Sem Informação    Sem Informação        Sem Informação
# 60320       Sem Informação    Sem Informação        Sem Informação
# 231721      Sem Informação    Sem Informação        Sem Informação
# 71          Sem Informação    Sem Informação        Sem Informação
#
#        Pais - Destino volta UF - Destino volta Cidade - Destino volta  \
# 112150       Sem Informação     Sem Informação         Sem Informação
# 55729        Sem Informação     Sem Informação         Sem Informação
# 93868        Sem Informação     Sem Informação         Sem Informação
# 306569       Sem Informação     Sem Informação         Sem Informação
# 84930        Sem Informação     Sem Informação         Sem Informação
# 69881        Sem Informação     Sem Informação         Sem Informação
# 251168       Sem Informação     Sem Informação         Sem Informação
# 60320        Sem Informação     Sem Informação         Sem Informação
# 231721       Sem Informação     Sem Informação         Sem Informação
# 71           Sem Informação     Sem Informação         Sem Informação
#
#        Valor da passagem Taxa de serviço
# 112150           1124,23             ,00
# 55729             472,77             ,00
# 93868             438,72             ,00
# 306569            344,47             ,00
# 84930             203,63             ,00
# 69881            1077,90             ,00
# 251168           1136,27            1,14
# 60320             446,33             ,00
# 231721            977,56             ,00
# 71                   ,00             ,00

# %%
"""
Vamos verificar algumas estatísticas básicas sobre colunas numéricas.
"""

df_passagens.describe()
# Out:
#        Identificador do processo de viagem
# count                            310816.00
# mean                           34950773.58
# std                           199220763.01
# min                            14046485.00
# 25%                            14763521.75
# 50%                            14929268.00
# 75%                            15105045.00
# max                          2018002771.00

# %%
"""
Vamos verificar algumas estatísticas básicas sobre as demais colunas.
"""

df_passagens.describe(include='object')
# Out:
#        Meio de transporte País - Origem ida   UF - Origem ida  \
# count              310816            310816            303560
# unique                  4               163                28
# top                 Aéreo            Brasil  Distrito Federal
# freq               293475            303557             80478
#
#        Cidade - Origem ida País - Destino ida  UF - Destino ida  \
# count               310816             310816            301096
# unique                 913                162                28
# top               Brasília             Brasil  Distrito Federal
# freq                 80478             301093             79346
#
#        Cidade - Destino ida País - Origem volta UF - Origem volta  \
# count                310816              310816            307823
# unique                  997                 111                28
# top                Brasília      Sem Informação    Sem Informação
# freq                  79346              287331            287331
#
#        Cidade - Origem volta Pais - Destino volta UF - Destino volta  \
# count                 310816               310816             310234
# unique                   541                  103                 28
# top           Sem Informação       Sem Informação     Sem Informação
# freq                  287331               287331             287331
#
#        Cidade - Destino volta Valor da passagem Taxa de serviço
# count                  310816            310816          310816
# unique                    352             72794            1641
# top            Sem Informação               ,00             ,00
# freq                   287331              3299          281439

# %%
"""
Tratamento em todas as colunas para colocar o valor None quando o valor for 'Não informado' ou NaN
"""
for c in df_passagens.columns:
    df_passagens[c] = df_passagens[c].apply(lambda x: x if x != 'Sem Informação' and pd.notnull(x) else None)

# %%
df_passagens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310816 entries, 0 to 310815
# Data columns (total 16 columns):
# Identificador do processo de viagem    310816 non-null int64
# Meio de transporte                     310816 non-null object
# País - Origem ida                      310816 non-null object
# UF - Origem ida                        303560 non-null object
# Cidade - Origem ida                    310816 non-null object
# País - Destino ida                     310816 non-null object
# UF - Destino ida                       301096 non-null object
# Cidade - Destino ida                   310816 non-null object
# País - Origem volta                    23485 non-null object
# UF - Origem volta                      20492 non-null object
# Cidade - Origem volta                  23485 non-null object
# Pais - Destino volta                   23485 non-null object
# UF - Destino volta                     22903 non-null object
# Cidade - Destino volta                 23485 non-null object
# Valor da passagem                      310816 non-null object
# Taxa de serviço                        310816 non-null object
# dtypes: int64(1), object(15)
# memory usage: 37.9+ MB

# %% [markdown]
# # Conversão das colunas para os tipos de dados corretos e padronização campos
# ---

# %%
"""
Verificamos valores nulos e tipos de dados com o método info() do dataframe.
"""

df_passagens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310816 entries, 0 to 310815
# Data columns (total 16 columns):
# Identificador do processo de viagem    310816 non-null int64
# Meio de transporte                     310816 non-null object
# País - Origem ida                      310816 non-null object
# UF - Origem ida                        303560 non-null object
# Cidade - Origem ida                    310816 non-null object
# País - Destino ida                     310816 non-null object
# UF - Destino ida                       301096 non-null object
# Cidade - Destino ida                   310816 non-null object
# País - Origem volta                    23485 non-null object
# UF - Origem volta                      20492 non-null object
# Cidade - Origem volta                  23485 non-null object
# Pais - Destino volta                   23485 non-null object
# UF - Destino volta                     22903 non-null object
# Cidade - Destino volta                 23485 non-null object
# Valor da passagem                      310816 non-null object
# Taxa de serviço                        310816 non-null object
# dtypes: int64(1), object(15)
# memory usage: 37.9+ MB

# %%
"""
A conversão pode ser feita utilizando o método apply da série que deseja converter.
"""
def converter_numero(valor):
    try:
        return float(valor.replace('.', '').replace(',', '.'))
    except:
        return np.nan

df_passagens_1 = df_passagens.copy()
df_passagens_1['Valor da passagem'] = \
    df_passagens_1['Valor da passagem'].apply(converter_numero)
df_passagens_1['Taxa de serviço'] =  \
    df_passagens_1['Taxa de serviço'].apply(converter_numero)

# %%
df_passagens_1[['Valor da passagem', 'Taxa de serviço']].head()
df_passagens_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310816 entries, 0 to 310815
# Data columns (total 16 columns):
# Identificador do processo de viagem    310816 non-null int64
# Meio de transporte                     310816 non-null object
# País - Origem ida                      310816 non-null object
# UF - Origem ida                        303560 non-null object
# Cidade - Origem ida                    310816 non-null object
# País - Destino ida                     310816 non-null object
# UF - Destino ida                       301096 non-null object
# Cidade - Destino ida                   310816 non-null object
# País - Origem volta                    23485 non-null object
# UF - Origem volta                      20492 non-null object
# Cidade - Origem volta                  23485 non-null object
# Pais - Destino volta                   23485 non-null object
# UF - Destino volta                     22903 non-null object
# Cidade - Destino volta                 23485 non-null object
# Valor da passagem                      310816 non-null float64
# Taxa de serviço                        310816 non-null float64
# dtypes: float64(2), int64(1), object(13)
# memory usage: 37.9+ MB

# %%
"""
Padronização das strings é interessante para que a ausência 
ou a presença de acentos não interfira em agrupamentos.
"""

from libs.texto import TratamentoTexto
def tratar_texto(valor):
    v = valor
    
    # somente realiza o tratamento se o texto não for nulo
    if v:
        # remove acentuação
        v = TratamentoTexto.remover_acentuacao(v)
        # converte para letras maiúsculas
        v = v.upper()
        
    return v

colunas = ['Meio de transporte',
       'País - Origem ida', 'UF - Origem ida', 'Cidade - Origem ida',
       'País - Destino ida', 'UF - Destino ida', 'Cidade - Destino ida',
       'País - Origem volta', 'UF - Origem volta', 'Cidade - Origem volta',
       'Pais - Destino volta', 'UF - Destino volta', 'Cidade - Destino volta']

# padronize as colunas da lista acima no dataframe df_passagens_1
for c in colunas:
    df_passagens_1[c] = df_passagens_1[c].apply(tratar_texto)

df_passagens_1.head(15)
# Out:
#     Identificador do processo de viagem Meio de transporte País - Origem ida  \
# 0                              14046485         RODOVIARIO            BRASIL
# 1                              14046485         RODOVIARIO            BRASIL
# 2                              14166390              AEREO            BRASIL
# 3                              14166390              AEREO            BRASIL
# 4                              14201345              AEREO            BRASIL
# 5                              14201345              AEREO            BRASIL
# 6                              14223544              AEREO            BRASIL
# 7                              14227023              AEREO            BRASIL
# 8                              14227023              AEREO            BRASIL
# 9                              14263076              AEREO            BRASIL
# 10                             14271222              AEREO            BRASIL
# 11                             14271246              AEREO            BRASIL
# 12                             14271246              AEREO            BRASIL
# 13                             14271246              AEREO            BRASIL
# 14                             14271246              AEREO            BRASIL
#
#       UF - Origem ida Cidade - Origem ida País - Destino ida  \
# 0               CEARA           FORTALEZA             BRASIL
# 1               CEARA              SOBRAL             BRASIL
# 2              PARANA            LONDRINA             BRASIL
# 3         MATO GROSSO               SINOP             BRASIL
# 4              PARANA            CURITIBA             BRASIL
# 5   RIO GRANDE DO SUL        PORTO ALEGRE             BRASIL
# 6    DISTRITO FEDERAL            BRASILIA            BOLIVIA
# 7           SAO PAULO      RIBEIRAO PRETO             BRASIL
# 8              PARANA            CURITIBA             BRASIL
# 9           SAO PAULO           SAO PAULO             CANADA
# 10   DISTRITO FEDERAL            BRASILIA             BRASIL
# 11           AMAZONAS              MANAUS             BRASIL
# 12   DISTRITO FEDERAL            BRASILIA             BRASIL
# 13         PERNAMBUCO              RECIFE             BRASIL
# 14               PARA               BELEM             BRASIL
#
#      UF - Destino ida     Cidade - Destino ida País - Origem volta  \
# 0               CEARA                   SOBRAL                None
# 1               CEARA                FORTALEZA                None
# 2         MATO GROSSO                    SINOP                None
# 3              PARANA                 LONDRINA                None
# 4   RIO GRANDE DO SUL             PORTO ALEGRE                None
# 5              PARANA                 CURITIBA                None
# 6                None  SANTA CRUZ DE LA SIERRA                None
# 7              PARANA                 CURITIBA                None
# 8           SAO PAULO           RIBEIRAO PRETO                None
# 9                None                VANCOUVER                None
# 10     RIO DE JANEIRO           RIO DE JANEIRO              BRASIL
# 11               PARA                    BELEM                None
# 12           AMAZONAS                   MANAUS                None
# 13   DISTRITO FEDERAL                 BRASILIA                None
# 14         PERNAMBUCO                   RECIFE                None
#
#    UF - Origem volta Cidade - Origem volta Pais - Destino volta  \
# 0               None                  None                 None
# 1               None                  None                 None
# 2               None                  None                 None
# 3               None                  None                 None
# 4               None                  None                 None
# 5               None                  None                 None
# 6               None                  None                 None
# 7               None                  None                 None
# 8               None                  None                 None
# 9               None                  None                 None
# 10    RIO DE JANEIRO        RIO DE JANEIRO               BRASIL
# 11              None                  None                 None
# 12              None                  None                 None
# 13              None                  None                 None
# 14              None                  None                 None
#
#    UF - Destino volta Cidade - Destino volta  Valor da passagem  \
# 0                None                   None              40.95
# 1                None                   None              33.25
# 2                None                   None             518.09
# 3                None                   None             665.38
# 4                None                   None             369.30
# 5                None                   None             170.45
# 6                None                   None             767.79
# 7                None                   None             635.28
# 8                None                   None             562.13
# 9                None                   None            3635.74
# 10   DISTRITO FEDERAL               BRASILIA             286.24
# 11               None                   None             622.47
# 12               None                   None             766.10
# 13               None                   None             636.15
# 14               None                   None             592.40
#
#     Taxa de serviço
# 0             13.51
# 1             10.97
# 2              0.00
# 3              0.00
# 4              0.00
# 5              0.00
# 6              0.00
# 7              0.00
# 8              0.00
# 9              0.00
# 10             0.00
# 11             0.00
# 12             0.00
# 13             0.00
# 14             0.00

# %% [markdown]
# # Você já está pensando em responder as questões?
#
# Não é uma boa idéia na maioria dos casos.

# %%
colunas_gb = ['País - Origem ida', 'UF - Origem ida', 'Cidade - Origem ida',
       'País - Destino ida', 'UF - Destino ida', 'Cidade - Destino ida']

colunas_selecao = ['País - Origem ida', 'UF - Origem ida', 
                   'Cidade - Origem ida',
       'País - Destino ida', 'UF - Destino ida', 
                   'Cidade - Destino ida', 'Valor da passagem']

df_passagens_1[colunas_selecao]\
    .groupby(colunas_gb, as_index=False)\
    .agg(['count', 'mean', 'median'])\
    .sort_values(('Valor da passagem', 'count'), ascending=False)\
    .head(10)
# Out:
#                                                                                                                   Valor da passagem  \
#                                                                                                                               count
# País - Origem ida UF - Origem ida   Cidade - Origem ida País - Destino ida UF - Destino ida  Cidade - Destino ida
# BRASIL            RIO DE JANEIRO    RIO DE JANEIRO      BRASIL             DISTRITO FEDERAL  BRASILIA                         14034
#                   DISTRITO FEDERAL  BRASILIA            BRASIL             RIO DE JANEIRO    RIO DE JANEIRO                   13933
#                                                                            SAO PAULO         SAO PAULO                        12271
#                   SAO PAULO         SAO PAULO           BRASIL             DISTRITO FEDERAL  BRASILIA                         12027
#                   RIO GRANDE DO SUL PORTO ALEGRE        BRASIL             DISTRITO FEDERAL  BRASILIA                          4092
#                   DISTRITO FEDERAL  BRASILIA            BRASIL             RIO GRANDE DO SUL PORTO ALEGRE                      3980
#                   RIO DE JANEIRO    RIO DE JANEIRO      BRASIL             SAO PAULO         SAO PAULO                         3603
#                   DISTRITO FEDERAL  BRASILIA            BRASIL             MINAS GERAIS      BELO HORIZONTE                    3535
#                   MINAS GERAIS      BELO HORIZONTE      BRASIL             DISTRITO FEDERAL  BRASILIA                          3499
#                   SAO PAULO         SAO PAULO           BRASIL             RIO DE JANEIRO    RIO DE JANEIRO                    3459
#
#                                                                                                                           \
#                                                                                                                     mean
# País - Origem ida UF - Origem ida   Cidade - Origem ida País - Destino ida UF - Destino ida  Cidade - Destino ida
# BRASIL            RIO DE JANEIRO    RIO DE JANEIRO      BRASIL             DISTRITO FEDERAL  BRASILIA             665.59
#                   DISTRITO FEDERAL  BRASILIA            BRASIL             RIO DE JANEIRO    RIO DE JANEIRO       621.79
#                                                                            SAO PAULO         SAO PAULO            696.73
#                   SAO PAULO         SAO PAULO           BRASIL             DISTRITO FEDERAL  BRASILIA             685.14
#                   RIO GRANDE DO SUL PORTO ALEGRE        BRASIL             DISTRITO FEDERAL  BRASILIA             767.78
#                   DISTRITO FEDERAL  BRASILIA            BRASIL             RIO GRANDE DO SUL PORTO ALEGRE         713.10
#                   RIO DE JANEIRO    RIO DE JANEIRO      BRASIL             SAO PAULO         SAO PAULO            354.40
#                   DISTRITO FEDERAL  BRASILIA            BRASIL             MINAS GERAIS      BELO HORIZONTE       643.77
#                   MINAS GERAIS      BELO HORIZONTE      BRASIL             DISTRITO FEDERAL  BRASILIA             643.06
#                   SAO PAULO         SAO PAULO           BRASIL             RIO DE JANEIRO    RIO DE JANEIRO       342.41
#
#
#                                                                                                                   median
# País - Origem ida UF - Origem ida   Cidade - Origem ida País - Destino ida UF - Destino ida  Cidade - Destino ida
# BRASIL            RIO DE JANEIRO    RIO DE JANEIRO      BRASIL             DISTRITO FEDERAL  BRASILIA             567.11
#                   DISTRITO FEDERAL  BRASILIA            BRASIL             RIO DE JANEIRO    RIO DE JANEIRO       527.03
#                                                                            SAO PAULO         SAO PAULO            559.69
#                   SAO PAULO         SAO PAULO           BRASIL             DISTRITO FEDERAL  BRASILIA             562.17
#                   RIO GRANDE DO SUL PORTO ALEGRE        BRASIL             DISTRITO FEDERAL  BRASILIA             674.64
#                   DISTRITO FEDERAL  BRASILIA            BRASIL             RIO GRANDE DO SUL PORTO ALEGRE         633.29
#                   RIO DE JANEIRO    RIO DE JANEIRO      BRASIL             SAO PAULO         SAO PAULO            263.77
#                   DISTRITO FEDERAL  BRASILIA            BRASIL             MINAS GERAIS      BELO HORIZONTE       626.43
#                   MINAS GERAIS      BELO HORIZONTE      BRASIL             DISTRITO FEDERAL  BRASILIA             637.05
#                   SAO PAULO         SAO PAULO           BRASIL             RIO DE JANEIRO    RIO DE JANEIRO       266.69

# %% [markdown]
# # Entendimento e organização dos dados
#
# Vamos olhar as variáveis de interesse separadamente.

# %% [markdown]
# ## Identificador do processo de viagem

# %%
df_passagens_1['Identificador do processo de viagem']\
    .value_counts()\
    .value_counts()
# Out:
# 2     117098
# 1      40411
# 3       6338
# 4       3436
# 5        319
# 6        187
# 7         42
# 8         36
# 10         5
# 9          3
# 14         2
# 11         2
# 13         1
# 12         1
# Name: Identificador do processo de viagem, dtype: int64

# %%
plt.rcParams['figure.figsize'] = (16.5,6)
df_passagens_1['Identificador do processo de viagem']\
    .value_counts()\
    .value_counts().plot.bar()
plt.xlabel('Quantidade de Trechos por ID de Viagem')
plt.ylabel('Quantidade de Registros')
#plt.yscale('log')
plt.grid(True)
plt.show()

# %%
'''
Exemplo de uma viagem com 3 trechos
'''
df_passagens_1[ df_passagens_1['Identificador do processo de viagem'] == 14756123 ]
# Out:
#        Identificador do processo de viagem Meio de transporte  \
# 74183                             14756123              AEREO
# 74184                             14756123              AEREO
# 74185                             14756123              AEREO
#
#       País - Origem ida   UF - Origem ida Cidade - Origem ida  \
# 74183            BRASIL             CEARA           FORTALEZA
# 74184            BRASIL             BAHIA            SALVADOR
# 74185            BRASIL  DISTRITO FEDERAL            BRASILIA
#
#       País - Destino ida  UF - Destino ida Cidade - Destino ida  \
# 74183             BRASIL             BAHIA             SALVADOR
# 74184             BRASIL  DISTRITO FEDERAL             BRASILIA
# 74185             BRASIL             CEARA            FORTALEZA
#
#       País - Origem volta UF - Origem volta Cidade - Origem volta  \
# 74183                None              None                  None
# 74184                None              None                  None
# 74185                None              None                  None
#
#       Pais - Destino volta UF - Destino volta Cidade - Destino volta  \
# 74183                 None               None                   None
# 74184                 None               None                   None
# 74185                 None               None                   None
#
#        Valor da passagem  Taxa de serviço
# 74183             285.86             0.00
# 74184             368.31             0.00
# 74185             552.33             0.00

# %%
'''
Exemplo de uma viagem com 5 trechos
'''
df_passagens_1[ df_passagens_1['Identificador do processo de viagem'] == 14825056 ]
# Out:
#         Identificador do processo de viagem Meio de transporte  \
# 106975                             14825056              AEREO
# 106976                             14825056              AEREO
# 106977                             14825056              AEREO
# 106978                             14825056              AEREO
# 106979                             14825056              AEREO
#
#                 País - Origem ida   UF - Origem ida  \
# 106975  ESTADOS UNIDOS DA AMERICA              None
# 106976  ESTADOS UNIDOS DA AMERICA              None
# 106977                     BRASIL  DISTRITO FEDERAL
# 106978  ESTADOS UNIDOS DA AMERICA              None
# 106979  ESTADOS UNIDOS DA AMERICA              None
#
#                   Cidade - Origem ida         País - Destino ida  \
# 106975                          MIAMI  ESTADOS UNIDOS DA AMERICA
# 106976                          MIAMI                     BRASIL
# 106977                       BRASILIA  ESTADOS UNIDOS DA AMERICA
# 106978                   INDIANAPOLIS  ESTADOS UNIDOS DA AMERICA
# 106979  CHARLOTTE - CAROLINA DO NORTE  ESTADOS UNIDOS DA AMERICA
#
#         UF - Destino ida           Cidade - Destino ida País - Origem volta  \
# 106975              None  CHARLOTTE - CAROLINA DO NORTE                None
# 106976  DISTRITO FEDERAL                       BRASILIA                None
# 106977              None                          MIAMI                None
# 106978              None                          MIAMI                None
# 106979              None                   INDIANAPOLIS                None
#
#        UF - Origem volta Cidade - Origem volta Pais - Destino volta  \
# 106975              None                  None                 None
# 106976              None                  None                 None
# 106977              None                  None                 None
# 106978              None                  None                 None
# 106979              None                  None                 None
#
#        UF - Destino volta Cidade - Destino volta  Valor da passagem  \
# 106975               None                   None            1762.05
# 106976               None                   None            1812.01
# 106977               None                   None            1762.05
# 106978               None                   None            1762.05
# 106979               None                   None            1762.05
#
#         Taxa de serviço
# 106975             0.00
# 106976             0.00
# 106977             0.00
# 106978             0.00
# 106979             0.00

# %%
'''
Exemplo de uma viagem com 14 trechos
'''
df_passagens_1[ df_passagens_1['Identificador do processo de viagem'] == 15190575 ]
# Out:
#         Identificador do processo de viagem Meio de transporte  \
# 262511                             15190575              AEREO
# 262512                             15190575              AEREO
# 262513                             15190575              AEREO
# 262514                             15190575              AEREO
# 262515                             15190575              AEREO
# 262516                             15190575              AEREO
# 262517                             15190575              AEREO
# 262518                             15190575              AEREO
# 262519                             15190575              AEREO
# 262520                             15190575              AEREO
# 262521                             15190575              AEREO
# 262522                             15190575              AEREO
# 262523                             15190575              AEREO
# 262524                             15190575              AEREO
#
#        País - Origem ida   UF - Origem ida Cidade - Origem ida  \
# 262511         FILIPINAS              None             MANILLA
# 262512         TAILANDIA              None             BANGCOC
# 262513              LAOS              None           VIENTIANE
# 262514         TAILANDIA              None             BANGCOC
# 262515           MYANMAR              None              YANGON
# 262516            BRASIL         SAO PAULO           SAO PAULO
# 262517            BRASIL  DISTRITO FEDERAL            BRASILIA
# 262518     COREIA DO SUL              None                SEUL
# 262519           MYANMAR              None         NAY PYI TAW
# 262520            BRASIL         SAO PAULO           SAO PAULO
# 262521         TAILANDIA              None             BANGCOC
# 262522         TAILANDIA              None             BANGCOC
# 262523        BANGLADESH              None                DACA
# 262524          MONGOLIA              None          ULAN-BATOR
#
#        País - Destino ida  UF - Destino ida Cidade - Destino ida  \
# 262511      COREIA DO SUL              None                 SEUL
# 262512               LAOS              None            VIENTIANE
# 262513          TAILANDIA              None              BANGCOC
# 262514            MYANMAR              None          NAY PYI TAW
# 262515          FILIPINAS              None              MANILLA
# 262516             BRASIL  DISTRITO FEDERAL             BRASILIA
# 262517             BRASIL         SAO PAULO            SAO PAULO
# 262518           MONGOLIA              None           ULAN-BATOR
# 262519            MYANMAR              None               YANGON
# 262520          TAILANDIA              None              BANGCOC
# 262521             BRASIL         SAO PAULO            SAO PAULO
# 262522         BANGLADESH              None                 DACA
# 262523          TAILANDIA              None              BANGCOC
# 262524          TAILANDIA              None              BANGCOC
#
#        País - Origem volta UF - Origem volta Cidade - Origem volta  \
# 262511                None              None                  None
# 262512                None              None                  None
# 262513                None              None                  None
# 262514                None              None                  None
# 262515                None              None                  None
# 262516                None              None                  None
# 262517                None              None                  None
# 262518                None              None                  None
# 262519                None              None                  None
# 262520                None              None                  None
# 262521                None              None                  None
# 262522                None              None                  None
# 262523                None              None                  None
# 262524                None              None                  None
#
#        Pais - Destino volta UF - Destino volta Cidade - Destino volta  \
# 262511                 None               None                   None
# 262512                 None               None                   None
# 262513                 None               None                   None
# 262514                 None               None                   None
# 262515                 None               None                   None
# 262516                 None               None                   None
# 262517                 None               None                   None
# 262518                 None               None                   None
# 262519                 None               None                   None
# 262520                 None               None                   None
# 262521                 None               None                   None
# 262522                 None               None                   None
# 262523                 None               None                   None
# 262524                 None               None                   None
#
#         Valor da passagem  Taxa de serviço
# 262511            1449.92             0.00
# 262512            1685.39             0.00
# 262513               0.00             0.00
# 262514            1425.89             0.00
# 262515            4305.86             0.00
# 262516             393.66             0.00
# 262517            1145.17             0.00
# 262518            1403.02             0.00
# 262519             608.52             0.00
# 262520            5533.52             0.00
# 262521             928.23             0.00
# 262522            4616.04             0.00
# 262523               0.00             0.00
# 262524            3916.40             0.00

# %%
df_passagens_1.describe(include='all')
# Out:
#         Identificador do processo de viagem Meio de transporte  \
# count                             310816.00             310816
# unique                                  nan                  4
# top                                     nan              AEREO
# freq                                    nan             293475
# mean                            34950773.58                NaN
# std                            199220763.01                NaN
# min                             14046485.00                NaN
# 25%                             14763521.75                NaN
# 50%                             14929268.00                NaN
# 75%                             15105045.00                NaN
# max                           2018002771.00                NaN
#
#        País - Origem ida   UF - Origem ida Cidade - Origem ida  \
# count             310816            303560              310816
# unique               148                28                 912
# top               BRASIL  DISTRITO FEDERAL            BRASILIA
# freq              303557             80478               80478
# mean                 NaN               NaN                 NaN
# std                  NaN               NaN                 NaN
# min                  NaN               NaN                 NaN
# 25%                  NaN               NaN                 NaN
# 50%                  NaN               NaN                 NaN
# 75%                  NaN               NaN                 NaN
# max                  NaN               NaN                 NaN
#
#        País - Destino ida  UF - Destino ida Cidade - Destino ida  \
# count              310816            301096               310816
# unique                146                28                  996
# top                BRASIL  DISTRITO FEDERAL             BRASILIA
# freq               301093             79346                79346
# mean                  NaN               NaN                  NaN
# std                   NaN               NaN                  NaN
# min                   NaN               NaN                  NaN
# 25%                   NaN               NaN                  NaN
# 50%                   NaN               NaN                  NaN
# 75%                   NaN               NaN                  NaN
# max                   NaN               NaN                  NaN
#
#        País - Origem volta UF - Origem volta Cidade - Origem volta  \
# count                23485             20492                 23485
# unique                  99                27                   540
# top                 BRASIL  DISTRITO FEDERAL              BRASILIA
# freq                 20492              5513                  5513
# mean                   NaN               NaN                   NaN
# std                    NaN               NaN                   NaN
# min                    NaN               NaN                   NaN
# 25%                    NaN               NaN                   NaN
# 50%                    NaN               NaN                   NaN
# 75%                    NaN               NaN                   NaN
# max                    NaN               NaN                   NaN
#
#        Pais - Destino volta UF - Destino volta Cidade - Destino volta  \
# count                 23485              22903                  23485
# unique                  101                 27                    351
# top                  BRASIL   DISTRITO FEDERAL               BRASILIA
# freq                  22903               7356                   7356
# mean                    NaN                NaN                    NaN
# std                     NaN                NaN                    NaN
# min                     NaN                NaN                    NaN
# 25%                     NaN                NaN                    NaN
# 50%                     NaN                NaN                    NaN
# 75%                     NaN                NaN                    NaN
# max                     NaN                NaN                    NaN
#
#         Valor da passagem  Taxa de serviço
# count           310816.00        310816.00
# unique                nan              nan
# top                   nan              nan
# freq                  nan              nan
# mean               826.33             3.04
# std               1061.66            67.42
# min                  0.00             0.00
# 25%                368.78             0.00
# 50%                598.90             0.00
# 75%                946.43             0.00
# max             102770.21          8729.52

# %%
"""
Vamos criar uma coluna que identifica se o trecho faz parte de uma viagem internacional ou não
"""

# vamos marcar trechos que são de origem ou destino internacional
df_passagens_1['Trecho Internacional'] = \
    (df_passagens_1['País - Origem ida'] != 'BRASIL') | (df_passagens_1['País - Destino ida'] != 'BRASIL') \
    | ( df_passagens_1['País - Origem volta'].notnull() & ((df_passagens_1['País - Origem volta'] != 'BRASIL') | (df_passagens_1['Pais - Destino volta'] != 'BRASIL'))) \

df_passagens_1[df_passagens_1['Trecho Internacional']].head()
# Out:
#     Identificador do processo de viagem Meio de transporte  \
# 6                              14223544              AEREO
# 9                              14263076              AEREO
# 16                             14292724              AEREO
# 17                             14296742              AEREO
# 18                             14302981              AEREO
#
#             País - Origem ida   UF - Origem ida Cidade - Origem ida  \
# 6                      BRASIL  DISTRITO FEDERAL            BRASILIA
# 9                      BRASIL         SAO PAULO           SAO PAULO
# 16  ESTADOS UNIDOS DA AMERICA              None              AUSTIN
# 17                     BRASIL         SAO PAULO           SAO PAULO
# 18                     BRASIL         SAO PAULO           SAO PAULO
#
#    País - Destino ida UF - Destino ida     Cidade - Destino ida  \
# 6             BOLIVIA             None  SANTA CRUZ DE LA SIERRA
# 9              CANADA             None                VANCOUVER
# 16              INDIA             None               NOVA DELHI
# 17          FILIPINAS             None                  MANILLA
# 18          FILIPINAS             None                  MANILLA
#
#    País - Origem volta UF - Origem volta Cidade - Origem volta  \
# 6                 None              None                  None
# 9                 None              None                  None
# 16               INDIA              None            NOVA DELHI
# 17                None              None                  None
# 18                None              None                  None
#
#          Pais - Destino volta UF - Destino volta Cidade - Destino volta  \
# 6                        None               None                   None
# 9                        None               None                   None
# 16  ESTADOS UNIDOS DA AMERICA               None                 AUSTIN
# 17                       None               None                   None
# 18                       None               None                   None
#
#     Valor da passagem  Taxa de serviço  Trecho Internacional
# 6              767.79             0.00                  True
# 9             3635.74             0.00                  True
# 16            3637.35             0.00                  True
# 17            6108.06             0.00                  True
# 18            6117.92             0.00                  True

# %%
# quais viagens possuem ao menos um trecho internacional
df_viagens_internacionais = \
    df_passagens_1[['Identificador do processo de viagem','Trecho Internacional']]\
    .groupby('Identificador do processo de viagem', as_index=False)\
    .max()

df_viagens_internacionais.head()
# Out:
#    Identificador do processo de viagem  Trecho Internacional
# 0                             14046485                 False
# 1                             14166390                 False
# 2                             14201345                 False
# 3                             14223544                  True
# 4                             14227023                 False

# %%
# quais processos de viagem possuem trechos internacionais
df_viagens_internacionais = df_viagens_internacionais.rename(columns={'Trecho Internacional': 'Viagem Internacional'})
df_viagens_internacionais.head()
# Out:
#    Identificador do processo de viagem  Viagem Internacional
# 0                             14046485                 False
# 1                             14166390                 False
# 2                             14201345                 False
# 3                             14223544                  True
# 4                             14227023                 False

# %%
df_passagens_2 = pd.merge(
        df_passagens_1, df_viagens_internacionais, how='left', 
                          left_on='Identificador do processo de viagem', right_on='Identificador do processo de viagem')
df_passagens_2.head()
# Out:
#    Identificador do processo de viagem Meio de transporte País - Origem ida  \
# 0                             14046485         RODOVIARIO            BRASIL
# 1                             14046485         RODOVIARIO            BRASIL
# 2                             14166390              AEREO            BRASIL
# 3                             14166390              AEREO            BRASIL
# 4                             14201345              AEREO            BRASIL
#
#   UF - Origem ida Cidade - Origem ida País - Destino ida   UF - Destino ida  \
# 0           CEARA           FORTALEZA             BRASIL              CEARA
# 1           CEARA              SOBRAL             BRASIL              CEARA
# 2          PARANA            LONDRINA             BRASIL        MATO GROSSO
# 3     MATO GROSSO               SINOP             BRASIL             PARANA
# 4          PARANA            CURITIBA             BRASIL  RIO GRANDE DO SUL
#
#   Cidade - Destino ida País - Origem volta UF - Origem volta  \
# 0               SOBRAL                None              None
# 1            FORTALEZA                None              None
# 2                SINOP                None              None
# 3             LONDRINA                None              None
# 4         PORTO ALEGRE                None              None
#
#   Cidade - Origem volta Pais - Destino volta UF - Destino volta  \
# 0                  None                 None               None
# 1                  None                 None               None
# 2                  None                 None               None
# 3                  None                 None               None
# 4                  None                 None               None
#
#   Cidade - Destino volta  Valor da passagem  Taxa de serviço  \
# 0                   None              40.95            13.51
# 1                   None              33.25            10.97
# 2                   None             518.09             0.00
# 3                   None             665.38             0.00
# 4                   None             369.30             0.00
#
#    Trecho Internacional  Viagem Internacional
# 0                 False                 False
# 1                 False                 False
# 2                 False                 False
# 3                 False                 False
# 4                 False                 False

# %%
df_passagens_2[df_passagens_2['Identificador do processo de viagem'] == 14342418]
# Out:
#     Identificador do processo de viagem Meio de transporte País - Origem ida  \
# 50                             14342418              AEREO            BRASIL
# 51                             14342418              AEREO            BRASIL
# 52                             14342418              AEREO         ARGENTINA
# 53                             14342418              AEREO            BRASIL
#
#    UF - Origem ida   Cidade - Origem ida País - Destino ida UF - Destino ida  \
# 50    MINAS GERAIS  GOVERNADOR VALADARES             BRASIL   RIO DE JANEIRO
# 51  RIO DE JANEIRO        RIO DE JANEIRO             BRASIL     MINAS GERAIS
# 52            None          BUENOS AIRES             BRASIL   RIO DE JANEIRO
# 53  RIO DE JANEIRO        RIO DE JANEIRO          ARGENTINA             None
#
#     Cidade - Destino ida País - Origem volta UF - Origem volta  \
# 50        RIO DE JANEIRO                None              None
# 51  GOVERNADOR VALADARES                None              None
# 52        RIO DE JANEIRO                None              None
# 53          BUENOS AIRES                None              None
#
#    Cidade - Origem volta Pais - Destino volta UF - Destino volta  \
# 50                  None                 None               None
# 51                  None                 None               None
# 52                  None                 None               None
# 53                  None                 None               None
#
#    Cidade - Destino volta  Valor da passagem  Taxa de serviço  \
# 50                   None             496.60             0.00
# 51                   None             233.50             0.00
# 52                   None            1008.63             0.00
# 53                   None            1398.93             0.00
#
#     Trecho Internacional  Viagem Internacional
# 50                 False                  True
# 51                 False                  True
# 52                  True                  True
# 53                  True                  True

# %%
df_passagens_g = df_passagens_2[df_passagens_2['Valor da passagem'] > 0.001] 
plt.rcParams['figure.figsize'] = 16,10
ax = sns.boxplot(y=df_passagens_g['Valor da passagem'], x=df_passagens_g['Trecho Internacional'].apply(lambda x: 'Internacional' if x else 'Nacional'))
ax.set_yscale('log')
ax.plot(x=[-1000, 1000], y=[2000,2000], color='red', linewidth=2, markersize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Observações
#
# * Número de trechos interfere no valor das passagens?
# * Trechos domésticos e viagens internacionais possuem valor superior aos dos trechos domésticos em viagens nacionais?
# * Trechos com valores muito baixos. Como isso é possível?

# %% [markdown]
# ## Meio de transporte
# ---

# %%
df_passagens_1['Meio de transporte'].value_counts().to_frame()
# Out:
#              Meio de transporte
# AEREO                    293475
# RODOVIARIO                14594
# FLUVIAL                    2733
# FERROVIARIO                  14

# %%
plt.rcParams["figure.figsize"] = 16, 4
ax = df_passagens_1['Meio de transporte'].value_counts().plot.barh()
ax.set_xscale('log')
plt.grid(True)
plt.show()

# %%
plt.rcParams['figure.figsize'] = 16,7
plt.rcParams['figure.dpi'] = 90

df_passagens_g = df_passagens_2[df_passagens_2['Valor da passagem']>0]

sns.boxplot(df_passagens_g['Meio de transporte'], df_passagens_g['Valor da passagem'], order=df_passagens_g['Meio de transporte'].drop_duplicates().sort_values())
plt.yscale('log')
plt.ylim = [0, 150000]
plt.grid(True)
plt.show()

# %% [markdown]
# ### Observações
#
# * Trechos aéreos acompanhados de outras modalidades possuem valor diferenciado?
# * Foco nos trechos aéreos

# %% [markdown]
# ## Taxa de Serviço
# ---

# %%
"""
Muitos registros zerados.
""" 
df_passagens_1['Taxa de serviço'].value_counts().head()
# Out:
# 0.00    281439
# 1.14      9121
# 0.01      4640
# 0.49      2043
# 5.00      1477
# Name: Taxa de serviço, dtype: int64

# %%
df_passagens_1['Taxa de serviço'].describe().to_frame()
# Out:
#        Taxa de serviço
# count        310816.00
# mean              3.04
# std              67.42
# min               0.00
# 25%               0.00
# 50%               0.00
# 75%               0.00
# max            8729.52

# %%
df_passagens_g = df_passagens_2[df_passagens_2['Taxa de serviço']>0]
plt.rcParams['figure.figsize'] = 16,8
sns.boxplot(x='Meio de transporte', y='Taxa de serviço', data=df_passagens_g, order=df_passagens_g['Meio de transporte'].drop_duplicates().sort_values())
plt.yscale('log')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Observações
#
# * Campo com poucas observações relevantes.
# * Talvez seja interessante investigar os outliers com valores altos.
# * Para o propósito levantado inicialmente, este campo não é necessário.

# %% [markdown]
# ## Origem, Destino, Ida e Volta

# %%
"""
Ocorrência da mesma variável em mais de uma coluna no dataset.
"""

df_passagens_2.head()
# Out:
#    Identificador do processo de viagem Meio de transporte País - Origem ida  \
# 0                             14046485         RODOVIARIO            BRASIL
# 1                             14046485         RODOVIARIO            BRASIL
# 2                             14166390              AEREO            BRASIL
# 3                             14166390              AEREO            BRASIL
# 4                             14201345              AEREO            BRASIL
#
#   UF - Origem ida Cidade - Origem ida País - Destino ida   UF - Destino ida  \
# 0           CEARA           FORTALEZA             BRASIL              CEARA
# 1           CEARA              SOBRAL             BRASIL              CEARA
# 2          PARANA            LONDRINA             BRASIL        MATO GROSSO
# 3     MATO GROSSO               SINOP             BRASIL             PARANA
# 4          PARANA            CURITIBA             BRASIL  RIO GRANDE DO SUL
#
#   Cidade - Destino ida País - Origem volta UF - Origem volta  \
# 0               SOBRAL                None              None
# 1            FORTALEZA                None              None
# 2                SINOP                None              None
# 3             LONDRINA                None              None
# 4         PORTO ALEGRE                None              None
#
#   Cidade - Origem volta Pais - Destino volta UF - Destino volta  \
# 0                  None                 None               None
# 1                  None                 None               None
# 2                  None                 None               None
# 3                  None                 None               None
# 4                  None                 None               None
#
#   Cidade - Destino volta  Valor da passagem  Taxa de serviço  \
# 0                   None              40.95            13.51
# 1                   None              33.25            10.97
# 2                   None             518.09             0.00
# 3                   None             665.38             0.00
# 4                   None             369.30             0.00
#
#    Trecho Internacional  Viagem Internacional
# 0                 False                 False
# 1                 False                 False
# 2                 False                 False
# 3                 False                 False
# 4                 False                 False

# %%
"""
Vamos organizar.
"""

df_passagens_3 = df_passagens_2.copy()

# %%
df_passagens_3[df_passagens_3['País - Origem volta'].notnull()].shape
# Out:
# (23485, 18)

# %%
"""
Vamos quebrar as linhas que possuem os trachos de ida e volta.
"""

df_passagens_3['Tipo Trecho'] = 'IDA'
df_passagens_3['Tipo Compra'] = 'SEPARADA'

voltas = []

for idx, df in df_passagens_3[
    df_passagens_3['País - Origem volta'].notnull()].iterrows():
    valor_passagem = df_passagens_3.at[idx, 'Valor da passagem'] / 2
    
    df_passagens_3.at[idx, 'Valor da passagem'] = valor_passagem
    df_passagens_3.at[idx, 'Tipo Compra'] = 'CONJUNTA'
    
    for ic in range(8,14):
        df_passagens_3.iat[idx, ic] = None
    
    df['Tipo Trecho'] = 'VOLTA'
    df['Tipo Compra'] = 'CONJUNTA'
    df['Valor da passagem'] = valor_passagem
    
    df['País - Origem ida'] = df['País - Origem volta']
    df['UF - Origem ida'] = df['UF - Origem volta']
    df['Cidade - Origem ida'] = df['Cidade - Origem volta']
    df['País - Destino ida'] = df['Pais - Destino volta']
    df['UF - Destino ida'] = df['UF - Destino volta']
    df['Cidade - Destino ida'] = df['Cidade - Destino volta']
    
    df['País - Origem volta'] = None
    df['UF - Origem volta'] = None
    df['Cidade - Origem volta'] = None
    df['Pais - Destino volta'] = None
    df['UF - Destino volta'] = None
    df['Cidade - Destino volta'] = None    
    
    voltas.append(df)

# %%
len(voltas)
# Out:
# 23485

# %%
df_voltas = pd.concat(voltas, ignore_index=False, axis=1).T
df_voltas.head()
# Out:
#    Identificador do processo de viagem Meio de transporte País - Origem ida  \
# 10                            14271222              AEREO            BRASIL
# 15                            14271373              AEREO            BRASIL
# 16                            14292724              AEREO             INDIA
# 21                            14303414              AEREO         NICARAGUA
# 22                            14303414              AEREO         NICARAGUA
#
#    UF - Origem ida Cidade - Origem ida         País - Destino ida  \
# 10  RIO DE JANEIRO      RIO DE JANEIRO                     BRASIL
# 15       SAO PAULO           SAO PAULO                     BRASIL
# 16            None          NOVA DELHI  ESTADOS UNIDOS DA AMERICA
# 21            None             MANAGUA                     MEXICO
# 22            None             MANAGUA                     MEXICO
#
#     UF - Destino ida Cidade - Destino ida País - Origem volta  \
# 10  DISTRITO FEDERAL             BRASILIA                None
# 15  DISTRITO FEDERAL             BRASILIA                None
# 16              None               AUSTIN                None
# 21              None     CIDADE DO MEXICO                None
# 22              None     CIDADE DO MEXICO                None
#
#    UF - Origem volta Cidade - Origem volta Pais - Destino volta  \
# 10              None                  None                 None
# 15              None                  None                 None
# 16              None                  None                 None
# 21              None                  None                 None
# 22              None                  None                 None
#
#    UF - Destino volta Cidade - Destino volta Valor da passagem  \
# 10               None                   None            143.12
# 15               None                   None            115.30
# 16               None                   None           1818.67
# 21               None                   None            869.09
# 22               None                   None            868.01
#
#    Taxa de serviço Trecho Internacional Viagem Internacional Tipo Trecho  \
# 10            0.00                False                False       VOLTA
# 15            0.00                False                False       VOLTA
# 16            0.00                 True                 True       VOLTA
# 21            0.00                 True                 True       VOLTA
# 22            0.00                 True                 True       VOLTA
#
#    Tipo Compra
# 10    CONJUNTA
# 15    CONJUNTA
# 16    CONJUNTA
# 21    CONJUNTA
# 22    CONJUNTA

# %%
df_passagens_4 = pd.concat([df_passagens_3, df_voltas])
df_passagens_4.head()
# Out:
#   Identificador do processo de viagem Meio de transporte País - Origem ida  \
# 0                            14046485         RODOVIARIO            BRASIL
# 1                            14046485         RODOVIARIO            BRASIL
# 2                            14166390              AEREO            BRASIL
# 3                            14166390              AEREO            BRASIL
# 4                            14201345              AEREO            BRASIL
#
#   UF - Origem ida Cidade - Origem ida País - Destino ida   UF - Destino ida  \
# 0           CEARA           FORTALEZA             BRASIL              CEARA
# 1           CEARA              SOBRAL             BRASIL              CEARA
# 2          PARANA            LONDRINA             BRASIL        MATO GROSSO
# 3     MATO GROSSO               SINOP             BRASIL             PARANA
# 4          PARANA            CURITIBA             BRASIL  RIO GRANDE DO SUL
#
#   Cidade - Destino ida País - Origem volta UF - Origem volta  \
# 0               SOBRAL                None              None
# 1            FORTALEZA                None              None
# 2                SINOP                None              None
# 3             LONDRINA                None              None
# 4         PORTO ALEGRE                None              None
#
#   Cidade - Origem volta Pais - Destino volta UF - Destino volta  \
# 0                  None                 None               None
# 1                  None                 None               None
# 2                  None                 None               None
# 3                  None                 None               None
# 4                  None                 None               None
#
#   Cidade - Destino volta Valor da passagem Taxa de serviço  \
# 0                   None             40.95           13.51
# 1                   None             33.25           10.97
# 2                   None            518.09            0.00
# 3                   None            665.38            0.00
# 4                   None            369.30            0.00
#
#   Trecho Internacional Viagem Internacional Tipo Trecho Tipo Compra
# 0                False                False         IDA    SEPARADA
# 1                False                False         IDA    SEPARADA
# 2                False                False         IDA    SEPARADA
# 3                False                False         IDA    SEPARADA
# 4                False                False         IDA    SEPARADA

# %%
print(df_passagens_3.shape)
print(df_passagens_4.shape)
# Out:
# (310816, 20)
# (334301, 20)

# %%
df_passagens_4 = df_passagens_4.sort_values(['Identificador do processo de viagem', 'Tipo Trecho']).reset_index(drop=True)
df_passagens_4.loc[10:11]
# Out:
#    Identificador do processo de viagem Meio de transporte País - Origem ida  \
# 10                            14271222              AEREO            BRASIL
# 11                            14271222              AEREO            BRASIL
#
#      UF - Origem ida Cidade - Origem ida País - Destino ida  UF - Destino ida  \
# 10  DISTRITO FEDERAL            BRASILIA             BRASIL    RIO DE JANEIRO
# 11    RIO DE JANEIRO      RIO DE JANEIRO             BRASIL  DISTRITO FEDERAL
#
#    Cidade - Destino ida País - Origem volta UF - Origem volta  \
# 10       RIO DE JANEIRO                None              None
# 11             BRASILIA                None              None
#
#    Cidade - Origem volta Pais - Destino volta UF - Destino volta  \
# 10                  None                 None               None
# 11                  None                 None               None
#
#    Cidade - Destino volta Valor da passagem Taxa de serviço  \
# 10                   None            143.12            0.00
# 11                   None            143.12            0.00
#
#    Trecho Internacional Viagem Internacional Tipo Trecho Tipo Compra
# 10                False                False         IDA    CONJUNTA
# 11                False                False       VOLTA    CONJUNTA

# %%
df_passagens_5 = df_passagens_4.drop(['País - Origem volta', 'UF - Origem volta', 'Cidade - Origem volta',
       'Pais - Destino volta', 'UF - Destino volta', 'Cidade - Destino volta'], axis=1)
df_passagens_5.head()
# Out:
#   Identificador do processo de viagem Meio de transporte País - Origem ida  \
# 0                            14046485         RODOVIARIO            BRASIL
# 1                            14046485         RODOVIARIO            BRASIL
# 2                            14166390              AEREO            BRASIL
# 3                            14166390              AEREO            BRASIL
# 4                            14201345              AEREO            BRASIL
#
#   UF - Origem ida Cidade - Origem ida País - Destino ida   UF - Destino ida  \
# 0           CEARA           FORTALEZA             BRASIL              CEARA
# 1           CEARA              SOBRAL             BRASIL              CEARA
# 2          PARANA            LONDRINA             BRASIL        MATO GROSSO
# 3     MATO GROSSO               SINOP             BRASIL             PARANA
# 4          PARANA            CURITIBA             BRASIL  RIO GRANDE DO SUL
#
#   Cidade - Destino ida Valor da passagem Taxa de serviço Trecho Internacional  \
# 0               SOBRAL             40.95           13.51                False
# 1            FORTALEZA             33.25           10.97                False
# 2                SINOP            518.09            0.00                False
# 3             LONDRINA            665.38            0.00                False
# 4         PORTO ALEGRE            369.30            0.00                False
#
#   Viagem Internacional Tipo Trecho Tipo Compra
# 0                False         IDA    SEPARADA
# 1                False         IDA    SEPARADA
# 2                False         IDA    SEPARADA
# 3                False         IDA    SEPARADA
# 4                False         IDA    SEPARADA

# %%
"""
Vamos utilizar apenas a sigla do estado.
"""
df_ufs = pd.read_csv('./dados/lista_ufs.csv', sep=';', encoding='latin1')
df_ufs['UF'] = df_ufs['UF'].apply(tratar_texto)

df_ufs.head()
# Out:
#          UF SG_UF
# 0      ACRE    AC
# 1   ALAGOAS    AL
# 2     AMAPA    AP
# 3  AMAZONAS    AM
# 4     BAHIA    BA

# %%
df_passagens_6 = pd.merge(df_passagens_5, df_ufs, left_on='UF - Origem ida', right_on='UF', how='left')
df_passagens_6.head()
# Out:
#   Identificador do processo de viagem Meio de transporte País - Origem ida  \
# 0                            14046485         RODOVIARIO            BRASIL
# 1                            14046485         RODOVIARIO            BRASIL
# 2                            14166390              AEREO            BRASIL
# 3                            14166390              AEREO            BRASIL
# 4                            14201345              AEREO            BRASIL
#
#   UF - Origem ida Cidade - Origem ida País - Destino ida   UF - Destino ida  \
# 0           CEARA           FORTALEZA             BRASIL              CEARA
# 1           CEARA              SOBRAL             BRASIL              CEARA
# 2          PARANA            LONDRINA             BRASIL        MATO GROSSO
# 3     MATO GROSSO               SINOP             BRASIL             PARANA
# 4          PARANA            CURITIBA             BRASIL  RIO GRANDE DO SUL
#
#   Cidade - Destino ida Valor da passagem Taxa de serviço Trecho Internacional  \
# 0               SOBRAL             40.95           13.51                False
# 1            FORTALEZA             33.25           10.97                False
# 2                SINOP            518.09            0.00                False
# 3             LONDRINA            665.38            0.00                False
# 4         PORTO ALEGRE            369.30            0.00                False
#
#   Viagem Internacional Tipo Trecho Tipo Compra           UF SG_UF
# 0                False         IDA    SEPARADA        CEARA    CE
# 1                False         IDA    SEPARADA        CEARA    CE
# 2                False         IDA    SEPARADA       PARANA    PR
# 3                False         IDA    SEPARADA  MATO GROSSO    MT
# 4                False         IDA    SEPARADA       PARANA    PR

# %%
df_passagens_6 = pd.merge(df_passagens_6, df_ufs, left_on='UF - Destino ida', right_on='UF', how='left')

# %%
df_passagens_6.head()
# Out:
#   Identificador do processo de viagem Meio de transporte País - Origem ida  \
# 0                            14046485         RODOVIARIO            BRASIL
# 1                            14046485         RODOVIARIO            BRASIL
# 2                            14166390              AEREO            BRASIL
# 3                            14166390              AEREO            BRASIL
# 4                            14201345              AEREO            BRASIL
#
#   UF - Origem ida Cidade - Origem ida País - Destino ida   UF - Destino ida  \
# 0           CEARA           FORTALEZA             BRASIL              CEARA
# 1           CEARA              SOBRAL             BRASIL              CEARA
# 2          PARANA            LONDRINA             BRASIL        MATO GROSSO
# 3     MATO GROSSO               SINOP             BRASIL             PARANA
# 4          PARANA            CURITIBA             BRASIL  RIO GRANDE DO SUL
#
#   Cidade - Destino ida Valor da passagem Taxa de serviço Trecho Internacional  \
# 0               SOBRAL             40.95           13.51                False
# 1            FORTALEZA             33.25           10.97                False
# 2                SINOP            518.09            0.00                False
# 3             LONDRINA            665.38            0.00                False
# 4         PORTO ALEGRE            369.30            0.00                False
#
#   Viagem Internacional Tipo Trecho Tipo Compra         UF_x SG_UF_x  \
# 0                False         IDA    SEPARADA        CEARA      CE
# 1                False         IDA    SEPARADA        CEARA      CE
# 2                False         IDA    SEPARADA       PARANA      PR
# 3                False         IDA    SEPARADA  MATO GROSSO      MT
# 4                False         IDA    SEPARADA       PARANA      PR
#
#                 UF_y SG_UF_y
# 0              CEARA      CE
# 1              CEARA      CE
# 2        MATO GROSSO      MT
# 3             PARANA      PR
# 4  RIO GRANDE DO SUL      RS

# %%
"""
Vamos concatenar Cidade e UF em uma única coluna
"""
df_passagens_7 = df_passagens_6.copy()
df_passagens_7['Origem'] = df_passagens_7['Cidade - Origem ida'] + '-' + df_passagens_7['SG_UF_x'].apply(lambda x: x if pd.notnull(x) else '')
df_passagens_7['Destino'] = df_passagens_7['Cidade - Destino ida'] + '-' + df_passagens_7['SG_UF_y'].apply(lambda x: x if pd.notnull(x) else '')
df_passagens_7.head()
# Out:
#   Identificador do processo de viagem Meio de transporte País - Origem ida  \
# 0                            14046485         RODOVIARIO            BRASIL
# 1                            14046485         RODOVIARIO            BRASIL
# 2                            14166390              AEREO            BRASIL
# 3                            14166390              AEREO            BRASIL
# 4                            14201345              AEREO            BRASIL
#
#   UF - Origem ida Cidade - Origem ida País - Destino ida   UF - Destino ida  \
# 0           CEARA           FORTALEZA             BRASIL              CEARA
# 1           CEARA              SOBRAL             BRASIL              CEARA
# 2          PARANA            LONDRINA             BRASIL        MATO GROSSO
# 3     MATO GROSSO               SINOP             BRASIL             PARANA
# 4          PARANA            CURITIBA             BRASIL  RIO GRANDE DO SUL
#
#   Cidade - Destino ida Valor da passagem Taxa de serviço Trecho Internacional  \
# 0               SOBRAL             40.95           13.51                False
# 1            FORTALEZA             33.25           10.97                False
# 2                SINOP            518.09            0.00                False
# 3             LONDRINA            665.38            0.00                False
# 4         PORTO ALEGRE            369.30            0.00                False
#
#   Viagem Internacional Tipo Trecho Tipo Compra         UF_x SG_UF_x  \
# 0                False         IDA    SEPARADA        CEARA      CE
# 1                False         IDA    SEPARADA        CEARA      CE
# 2                False         IDA    SEPARADA       PARANA      PR
# 3                False         IDA    SEPARADA  MATO GROSSO      MT
# 4                False         IDA    SEPARADA       PARANA      PR
#
#                 UF_y SG_UF_y        Origem          Destino
# 0              CEARA      CE  FORTALEZA-CE        SOBRAL-CE
# 1              CEARA      CE     SOBRAL-CE     FORTALEZA-CE
# 2        MATO GROSSO      MT   LONDRINA-PR         SINOP-MT
# 3             PARANA      PR      SINOP-MT      LONDRINA-PR
# 4  RIO GRANDE DO SUL      RS   CURITIBA-PR  PORTO ALEGRE-RS

# %%
"""
Selecionamos apenas as colunas desejadas e renomeamos elas
"""
df_passagens_7 = df_passagens_7[['Identificador do processo de viagem', 'Origem', 'Destino', 'Valor da passagem', 'Taxa de serviço', 'Trecho Internacional', 'Viagem Internacional', 'Tipo Trecho', 'Tipo Compra', 'Meio de transporte']]
df_passagens_7.columns = ['ID_VIAGEM', 'ORIGEM', 'DESTINO', 'VALOR', 'TAXA', 'TRECHO_INT', 'VIAGEM_INT', 'TIPO_TRECHO', 'TIPO_COMPRA', 'MEIO_TRANSPORTE']
df_passagens_7['VIAGEM_INT'] = df_passagens_7['VIAGEM_INT'].apply(lambda x: 1 if x else 0)
df_passagens_7['TRECHO_INT'] = df_passagens_7['TRECHO_INT'].apply(lambda x: 1 if x else 0)
df_passagens_7.head()
# Out:
#   ID_VIAGEM        ORIGEM          DESTINO  VALOR  TAXA  TRECHO_INT  \
# 0  14046485  FORTALEZA-CE        SOBRAL-CE  40.95 13.51           0
# 1  14046485     SOBRAL-CE     FORTALEZA-CE  33.25 10.97           0
# 2  14166390   LONDRINA-PR         SINOP-MT 518.09  0.00           0
# 3  14166390      SINOP-MT      LONDRINA-PR 665.38  0.00           0
# 4  14201345   CURITIBA-PR  PORTO ALEGRE-RS 369.30  0.00           0
#
#    VIAGEM_INT TIPO_TRECHO TIPO_COMPRA MEIO_TRANSPORTE
# 0           0         IDA    SEPARADA      RODOVIARIO
# 1           0         IDA    SEPARADA      RODOVIARIO
# 2           0         IDA    SEPARADA           AEREO
# 3           0         IDA    SEPARADA           AEREO
# 4           0         IDA    SEPARADA           AEREO

# %%
df_passagens_7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 334301 entries, 0 to 334300
# Data columns (total 10 columns):
# ID_VIAGEM          334301 non-null object
# ORIGEM             334301 non-null object
# DESTINO            334301 non-null object
# VALOR              334301 non-null object
# TAXA               334301 non-null object
# TRECHO_INT         334301 non-null int64
# VIAGEM_INT         334301 non-null int64
# TIPO_TRECHO        334301 non-null object
# TIPO_COMPRA        334301 non-null object
# MEIO_TRANSPORTE    334301 non-null object
# dtypes: int64(2), object(8)
# memory usage: 28.1+ MB

# %%
"""
Fazemos novamente um tratamento de tipos de dados para as colunas
"""
df_passagens_7['VALOR'] = df_passagens_7['VALOR'].astype(np.float64)
df_passagens_7['TAXA'] = df_passagens_7['TAXA'].astype(np.float64)

df_passagens_7['ORIGEM'] = df_passagens_7['ORIGEM'].astype('category')
df_passagens_7['DESTINO'] = df_passagens_7['DESTINO'].astype('category')

df_passagens_7['TIPO_TRECHO'] = df_passagens_7['TIPO_TRECHO'].astype('category')
df_passagens_7['TIPO_COMPRA'] = df_passagens_7['TIPO_COMPRA'].astype('category')

df_passagens_7.head()
# Out:
#   ID_VIAGEM        ORIGEM          DESTINO  VALOR  TAXA  TRECHO_INT  \
# 0  14046485  FORTALEZA-CE        SOBRAL-CE  40.95 13.51           0
# 1  14046485     SOBRAL-CE     FORTALEZA-CE  33.25 10.97           0
# 2  14166390   LONDRINA-PR         SINOP-MT 518.09  0.00           0
# 3  14166390      SINOP-MT      LONDRINA-PR 665.38  0.00           0
# 4  14201345   CURITIBA-PR  PORTO ALEGRE-RS 369.30  0.00           0
#
#    VIAGEM_INT TIPO_TRECHO TIPO_COMPRA MEIO_TRANSPORTE
# 0           0         IDA    SEPARADA      RODOVIARIO
# 1           0         IDA    SEPARADA      RODOVIARIO
# 2           0         IDA    SEPARADA           AEREO
# 3           0         IDA    SEPARADA           AEREO
# 4           0         IDA    SEPARADA           AEREO

# %%
"""
É possível ver que não existem mais registros com informações nulas e os tipos de dados estão adequados para cada situação.
"""
df_passagens_7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 334301 entries, 0 to 334300
# Data columns (total 10 columns):
# ID_VIAGEM          334301 non-null object
# ORIGEM             334301 non-null category
# DESTINO            334301 non-null category
# VALOR              334301 non-null float64
# TAXA               334301 non-null float64
# TRECHO_INT         334301 non-null int64
# VIAGEM_INT         334301 non-null int64
# TIPO_TRECHO        334301 non-null category
# TIPO_COMPRA        334301 non-null category
# MEIO_TRANSPORTE    334301 non-null object
# dtypes: category(4), float64(2), int64(2), object(2)
# memory usage: 19.9+ MB

# %%
"""
Vamos eliminar todas as viagens internacionais.
Vamos também manter apenas o meio de transporte AEREO
"""
df_passagens_8 = df_passagens_7[df_passagens_7['VIAGEM_INT'] == False]
df_passagens_8 = df_passagens_8[df_passagens_8['MEIO_TRANSPORTE'] == 'AEREO'].reset_index(drop=True)
df_passagens_8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296486 entries, 0 to 296485
# Data columns (total 10 columns):
# ID_VIAGEM          296486 non-null object
# ORIGEM             296486 non-null category
# DESTINO            296486 non-null category
# VALOR              296486 non-null float64
# TAXA               296486 non-null float64
# TRECHO_INT         296486 non-null int64
# VIAGEM_INT         296486 non-null int64
# TIPO_TRECHO        296486 non-null category
# TIPO_COMPRA        296486 non-null category
# MEIO_TRANSPORTE    296486 non-null object
# dtypes: category(4), float64(2), int64(2), object(2)
# memory usage: 15.4+ MB

# %%
df_passagens_8[['ORIGEM','DESTINO']]\
    .groupby(['ORIGEM','DESTINO'])\
    .size().reset_index(name='TOTAL').sort_values('TOTAL', ascending=False).head(10)
# Out:
#                  ORIGEM            DESTINO  TOTAL
# 3503  RIO DE JANEIRO-RJ        BRASILIA-DF  14987
# 615         BRASILIA-DF  RIO DE JANEIRO-RJ  14825
# 3981       SAO PAULO-SP        BRASILIA-DF  12750
# 632         BRASILIA-DF       SAO PAULO-SP  12592
# 3071    PORTO ALEGRE-RS        BRASILIA-DF   4252
# 606         BRASILIA-DF    PORTO ALEGRE-RS   4179
# 536         BRASILIA-DF  BELO HORIZONTE-MG   3802
# 367   BELO HORIZONTE-MG        BRASILIA-DF   3783
# 4037       SAO PAULO-SP  RIO DE JANEIRO-RJ   3767
# 3585  RIO DE JANEIRO-RJ       SAO PAULO-SP   3725

# %%
"""
Vamos calcular a quantidade de ocorrências, média, 
mediana e desvio padrão por trecho
"""
df_passagens_8[['ORIGEM','DESTINO','VALOR']]\
    .groupby(['ORIGEM','DESTINO'], as_index=False)\
    .aggregate({'VALOR': {'mean': 'mean', 
                          'median': 'median', 
                          'std': 'std', 
                          'tamanho': len}})\
    .sort_values(('VALOR', 'tamanho'), ascending=False)\
    .reset_index(drop=True)\
    .head(10)
# Out:
#               ORIGEM            DESTINO  VALOR
#                                           mean median    std  tamanho
# 0  RIO DE JANEIRO-RJ        BRASILIA-DF 624.96 533.73 382.71 14987.00
# 1        BRASILIA-DF  RIO DE JANEIRO-RJ 579.50 507.03 344.59 14825.00
# 2       SAO PAULO-SP        BRASILIA-DF 664.27 550.65 376.58 12750.00
# 3        BRASILIA-DF       SAO PAULO-SP 651.24 534.25 377.76 12592.00
# 4    PORTO ALEGRE-RS        BRASILIA-DF 728.53 651.45 364.53  4252.00
# 5        BRASILIA-DF    PORTO ALEGRE-RS 688.21 613.81 335.31  4179.00
# 6        BRASILIA-DF  BELO HORIZONTE-MG 597.71 584.93 328.91  3802.00
# 7  BELO HORIZONTE-MG        BRASILIA-DF 594.83 606.89 330.00  3783.00
# 8       SAO PAULO-SP  RIO DE JANEIRO-RJ 328.89 263.01 228.07  3767.00
# 9  RIO DE JANEIRO-RJ       SAO PAULO-SP 325.05 251.44 229.67  3725.00

# %%
filtro_a = (df_passagens_7['ORIGEM'] == 'RIO DE JANEIRO-RJ') & (df_passagens_7['DESTINO'] == 'BRASILIA-DF')
filtro_b = (df_passagens_7['ORIGEM'] == 'BRASILIA-DF') & (df_passagens_7['DESTINO'] == 'RIO DE JANEIRO-RJ')

df_passagens_g = df_passagens_7[ (filtro_a | filtro_b) ].copy()

df_passagens_g['ORIGEM'] = df_passagens_g['ORIGEM'].astype(str)

ax = sns.boxplot(x='VALOR', y='ORIGEM', data=df_passagens_g, hue='TIPO_COMPRA')

ax.xaxis.set_minor_locator(matplotlib.ticker.MultipleLocator(100))
plt.grid(True)
plt.show()

# %%
df_passagens_g.describe()
# Out:
#          VALOR     TAXA  TRECHO_INT  VIAGEM_INT
# count 29903.00 29903.00    29903.00    29903.00
# mean    602.09     2.03        0.00        0.00
# std     365.51    38.55        0.00        0.06
# min       0.00     0.00        0.00        0.00
# 25%     333.84     0.00        0.00        0.00
# 50%     517.71     0.00        0.00        0.00
# 75%     740.02     0.00        0.00        0.00
# max    3575.03  1760.90        0.00        1.00

# %%
"""
Desenhe um histograma com os valores encontrados 
para o trecho mais frequente. (Considere ida ou volta)

Identifique os outliers utilizando as marcações do boxplot.

IQR = q3 - q1
limite inferior = q1 - 1.5*IQR
limite superior = q3 + 1.5*IQR
"""

df_passagens_g['VALOR'].hist(bins=75)

q1, q2, q3 = df_passagens_g['VALOR'].quantile([.25,.5,.75])

iqr = q3 - q1
li = q1 - 1.5*iqr
ls = q3 + 1.5*iqr

plt.plot([q1, q1], [0, 2400], 
         linewidth=4, markersize=12, linestyle='dashed', color='yellow')

plt.plot([q2, q2], [0, 2400], 
         linewidth=4, markersize=12, linestyle='dashed', color='red')

plt.plot([q3, q3], [0, 2400], 
         linewidth=4, markersize=12, linestyle='dashed', color='yellow')

plt.plot([li, li], [0, 2400], 
         linewidth=4, markersize=12, linestyle='dashed', color='black')

plt.plot([ls, ls], [0, 2400], 
         linewidth=4, markersize=12, linestyle='dashed', color='black')

plt.show()

# %%
ls
# Out:
# 1349.29

# %%
df_passagens_g[df_passagens_g['VALOR']>ls].shape
# Out:
# (1826, 10)

# %%
"""
Utilize o dataframe df_viagem para incluir as informações de Órgão Solicitante e Motivo da Viagem
"""
df_viagem = pd.read_csv('dados/c04_passagens/2018_Viagem.csv.zip', sep=';', encoding='iso-8859-1', error_bad_lines=False, quotechar="\"")
df_viagem.head()
# Out:
# b'Skipping line 802: expected 16 fields, saw 17\nSkipping line 1319: expected 16 fields, saw 17\nSkipping line 1447: expected 16 fields, saw 17\nSkipping line 1557: expected 16 fields, saw 17\nSkipping line 3677: expected 16 fields, saw 17\nSkipping line 5423: expected 16 fields, saw 17\nSkipping line 10001: expected 16 fields, saw 17\nSkipping line 10128: expected 16 fields, saw 22\nSkipping line 12242: expected 16 fields, saw 18\nSkipping line 12942: expected 16 fields, saw 22\nSkipping line 13201: expected 16 fields, saw 22\nSkipping line 13220: expected 16 fields, saw 22\nSkipping line 13253: expected 16 fields, saw 22\nSkipping line 13261: expected 16 fields, saw 22\nSkipping line 15560: expected 16 fields, saw 17\nSkipping line 15571: expected 16 fields, saw 19\nSkipping line 16778: expected 16 fields, saw 19\nSkipping line 16917: expected 16 fields, saw 17\nSkipping line 17055: expected 16 fields, saw 19\nSkipping line 17394: expected 16 fields, saw 17\nSkipping line 18245: expected 16 fields, saw 18\nSkipping line 18937: expected 16 fields, saw 17\nSkipping line 21493: expected 16 fields, saw 17\nSkipping line 22146: expected 16 fields, saw 18\nSkipping line 22154: expected 16 fields, saw 18\nSkipping line 22594: expected 16 fields, saw 17\nSkipping line 22666: expected 16 fields, saw 19\nSkipping line 22762: expected 16 fields, saw 17\nSkipping line 23916: expected 16 fields, saw 17\nSkipping line 23942: expected 16 fields, saw 17\nSkipping line 23955: expected 16 fields, saw 17\nSkipping line 23969: expected 16 fields, saw 17\nSkipping line 23984: expected 16 fields, saw 17\nSkipping line 25564: expected 16 fields, saw 17\nSkipping line 27231: expected 16 fields, saw 19\nSkipping line 27655: expected 16 fields, saw 17\nSkipping line 27725: expected 16 fields, saw 17\nSkipping line 27729: expected 16 fields, saw 21\nSkipping line 27759: expected 16 fields, saw 17\nSkipping line 29735: expected 16 fields, saw 18\nSkipping line 30966: expected 16 fields, saw 17\nSkipping line 31374: expected 16 fields, saw 19\n'
# b'Skipping line 36061: expected 16 fields, saw 17\nSkipping line 38532: expected 16 fields, saw 17\nSkipping line 38680: expected 16 fields, saw 19\nSkipping line 38910: expected 16 fields, saw 18\nSkipping line 39200: expected 16 fields, saw 18\nSkipping line 39584: expected 16 fields, saw 17\nSkipping line 40752: expected 16 fields, saw 17\nSkipping line 43053: expected 16 fields, saw 17\nSkipping line 45955: expected 16 fields, saw 19\nSkipping line 46657: expected 16 fields, saw 17\nSkipping line
fields, saw 17\nSkipping line 573729: expected 16 fields, saw 19\nSkipping line 573890: expected 16 fields, saw 19\nSkipping line 574826: expected 16 fields, saw 17\nSkipping line 576525: expected 16 fields, saw 17\nSkipping line 577998: expected 16 fields, saw 17\nSkipping line 578233: expected 16 fields, saw 17\nSkipping line 579068: expected 16 fields, saw 17\nSkipping line 579809: expected 16 fields, saw 18\nSkipping line 579814: expected 16 fields, saw 17\nSkipping line 580049: expected 16 fields, saw 17\nSkipping line 580096: expected 16 fields, saw 17\nSkipping line 580109: expected 16 fields, saw 17\nSkipping line 580166: expected 16 fields, saw 17\nSkipping line 581277: expected 16 fields, saw 17\nSkipping line 581440: expected 16 fields, saw 17\nSkipping line 583019: expected 16 fields, saw 21\nSkipping line 583249: expected 16 fields, saw 20\nSkipping line 583276: expected 16 fields, saw 18\nSkipping line 585514: expected 16 fields, saw 19\nSkipping line 586357: expected 16 fields, saw 17\nSkipping line 586885: expected 16 fields, saw 17\nSkipping line 589667: expected 16 fields, saw 18\n'
# b'Skipping line 591351: expected 16 fields, saw 17\nSkipping line 592982: expected 16 fields, saw 17\nSkipping line 593029: expected 16 fields, saw 17\nSkipping line 593245: expected 16 fields, saw 17\nSkipping line 597442: expected 16 fields, saw 17\nSkipping line 599659: expected 16 fields, saw 20\nSkipping line 600600: expected 16 fields, saw 20\nSkipping line 600622: expected 16 fields, saw 20\nSkipping line 600651: expected 16 fields, saw 20\nSkipping line 600750: expected 16 fields, saw 17\nSkipping line 600818: expected 16 fields, saw 17\nSkipping line 602269: expected 16 fields, saw 17\nSkipping line 603743: expected 16 fields, saw 17\nSkipping line 604062: expected 16 fields, saw 17\n'
#    Identificador do processo de viagem   Situação  Código do órgão superior  \
# 0                             13501576  Realizada                     36000
# 1                             14046485  Realizada                     26000
# 2                             14108743  Realizada                     26000
# 3                             14112304  Realizada                     26000
# 4                             14142324  Realizada                     44000
#
#         Nome do órgão superior  Código órgão solicitante  \
# 0          MINISTERIO DA SAUDE                     36201
# 1       MINISTERIO DA EDUCACAO                     26405
# 2       MINISTERIO DA EDUCACAO                     26258
# 3       MINISTERIO DA EDUCACAO                     26279
# 4  MINISTERIO DO MEIO AMBIENTE                     44207
#
#                           Nome órgão solicitante    CPF viajante  \
# 0                          FUNDACAO OSWALDO CRUZ  ***.637.54*-**
# 1         INST.FED.DE EDUC.,CIENC.E TEC.DO CEARA  ***.061.02*-**
# 2     UNIVERSIDADE TECNOLOGICA FEDERAL DO PARANA  ***.414.38*-**
# 3         FUNDACAO UNIVERSIDADE FEDERAL DO PIAUI  ***.836.65*-**
# 4  INST.CHICO MENDES DE CONSER.DA BIODIVERSIDADE  ***.852.04*-**
#
#                                    Nome  \
# 0  ELIANE CALDAS DO NASCIMENTO OLIVEIRA
# 1          REGINA LUCIA BEZERRA VASQUES
# 2        JULIANA BORTOLI RODRIGUES MEES
# 3       FRANCISCO DE ASSIS SINIMBU NETO
# 4                   CARINA TOSTES ABREU
#
#                                    Cargo  Período - Data de início  \
# 0           PESQUISADOR EM SAUDE PUBLICA                  20180210
# 1                                    NaN                  20180223
# 2  PROFESSOR ENS BASICO TECN TECNOLOGICO                  20180117
# 3  PROFESSOR ENS BASICO TECN TECNOLOGICO                  20180104
# 4                     ANALISTA AMBIENTAL                  20180108
#
#    Período - Data de fim                            Destinos  \
# 0               20180302                    Coimbra/Portugal
# 1               20180225                          Meruoca/CE
# 2               20180216                     Lisboa/Portugal
# 3               20180106                        Bom Jesus/PI
# 4               20180407  Honolulu/Estados Unidos da América
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                           Motivo  \
# 0          PARTICIPAÇÃO EM PROJETOS DE PESQUISA DESENVOLVIDOS PELO BLH/IFF, EM CURSOS DE PÓS-GRADUAÇÃO STRITO CENSO, APERFEIÇOAMENTO, ATUALIZAÇÃO E SENSIBILIZAÇÃO NA CAPACITAÇÃO DE SERVIDORES PROFISSIONAIS DA ÁREA DE SAÚDE, DENTRE OUTROS CURSOS TREINAMENTOS RELACIONADOS À PROMOÇÃO DO ALEITAMENTO MATERNO; PRODUÇÃO ACADÊMICA COM ARTIGOS PARA SEREM PUBLICADOS E ORIENTAÇÃO DE ALUNOS; ASSISTÊNCIA AMBULATORIAL E HOSPITALAR E REUNIÕES E PLANEJAMENTOS.
# 1                                                                                                                                                                                                                                                                                                                                    Realizar o  encontro presencial da Disciplina ESPANHOL BÁSICO, no Polo de MERUOCA no dia 24/02/2018, no turno MANHÃ E TARDE
# 2  Estágio/Intercâmbio Internacional no IPPORTO PORTUGAL. Para o desenvolvimento do projeto  Inovações Metodológicas na caracterização e no tratamento de resíduos agroindustriais aplicadas para o ensino da graduação de engenharia ambiental", APROVADO no Edital PROGRAD 10/2017 para o desenvolvimento de projetos inovadores de caráter internacional no ensino na graduação, no qual consta como proponente a professora JULIANA BORTOLI RODRIGUES MEES."
# 3                                                                                                                                                                                                                                                                                                                    o mesmo participará de solenidades de FORMATURAS DOS CURSOS REGULARES do Colégio Técnico de Bom Jesus- CTBJ, conforme programação em anexo.
# 4                                                                Trata o presente processo da solicitação de Licença para Capacitação no exterior, com ônus limitado, Curso de inglês integral (English program for full-time students) - 240h - Academia Language School - presencial, em Honolulu/HI/USA, a ser realizado no período de 08 de janeiro de 2018 a 07 de abril de 2018, totalizando 90 dias. Conforme autorizado no processo 02070.004142/2017-02
#
#   Valor diárias Valor passagens Valor outros gastos
# 0           ,00             ,00                 ,00
# 1        537,50           98,68                 ,00
# 2           ,00             ,00                 ,00
# 3        487,11             ,00                 ,00
# 4           ,00             ,00                 ,00

# %%
df_viagem.head(1)
# Out:
#    Identificador do processo de viagem   Situação  Código do órgão superior  \
# 0                             13501576  Realizada                     36000
#
#   Nome do órgão superior  Código órgão solicitante Nome órgão solicitante  \
# 0    MINISTERIO DA SAUDE                     36201  FUNDACAO OSWALDO CRUZ
#
#      CPF viajante                                  Nome  \
# 0  ***.637.54*-**  ELIANE CALDAS DO NASCIMENTO OLIVEIRA
#
#                           Cargo  Período - Data de início  \
# 0  PESQUISADOR EM SAUDE PUBLICA                  20180210
#
#    Período - Data de fim          Destinos  \
# 0               20180302  Coimbra/Portugal
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                   Motivo  \
# 0  PARTICIPAÇÃO EM PROJETOS DE PESQUISA DESENVOLVIDOS PELO BLH/IFF, EM CURSOS DE PÓS-GRADUAÇÃO STRITO CENSO, APERFEIÇOAMENTO, ATUALIZAÇÃO E SENSIBILIZAÇÃO NA CAPACITAÇÃO DE SERVIDORES PROFISSIONAIS DA ÁREA DE SAÚDE, DENTRE OUTROS CURSOS TREINAMENTOS RELACIONADOS À PROMOÇÃO DO ALEITAMENTO MATERNO; PRODUÇÃO ACADÊMICA COM ARTIGOS PARA SEREM PUBLICADOS E ORIENTAÇÃO DE ALUNOS; ASSISTÊNCIA AMBULATORIAL E HOSPITALAR E REUNIÕES E PLANEJAMENTOS.
#
#   Valor diárias Valor passagens Valor outros gastos
# 0           ,00             ,00                 ,00

# %%
"""
Identifique os órgãos com mais ocorrências entre os outliers.
"""
df_passagens_g['ID_VIAGEM'] = df_passagens_g['ID_VIAGEM'].astype(np.int64)
df_completo = pd.merge(
    df_passagens_g[df_passagens_g['VALOR']>ls],
    df_viagem[['Identificador do processo de viagem', 'Nome órgão solicitante', 'Motivo']],
    how='left',
    left_on='ID_VIAGEM',
    right_on='Identificador do processo de viagem'
)
df_completo['Nome órgão solicitante'].value_counts().to_frame()
# Out:
#                                                                              Nome órgão solicitante
# COMANDO DA AERONAUTICA                                                                          116
# MINISTERIO DA EDUCACAO - UNIDADES COM VÍNCULO DIRETO                                             95
# PRESIDENCIA DA REPUBLICA - UNIDADES COM VÍNCULO DIRETO                                           87
# COMANDO DO EXERCITO                                                                              84
# INST.NACIONAL DE EST.E PESQUISAS EDUCACIONAIS                                                    67
# COMISSAO NACIONAL DE ENERGIA NUCLEAR                                                             58
# MINISTERIO DA FAZENDA - UNIDADES COM VÍNCULO DIRETO                                              51
# AGENCIA NACIONAL DO PETROLEO                                                                     51
# MINISTERIO DA SAUDE - UNIDADES COM VÍNCULO DIRETO                                                50
# MINIST.DA CIENCIA,TECNOL.,INOV.E COMUNICACOES - UNIDADES COM VÍNCULO DIRETO                      49
# MINISTERIO DAS CIDADES - UNIDADES COM VÍNCULO DIRETO                                             48
# FUND.INST.BRASILEIRO DE GEOG.E ESTATISTICA                                                       45
# MINISTERIO DA DEFESA - UNIDADES COM VÍNCULO DIRETO                                               43
# SECRETARIA DE DIREITOS HUMANOS                                                                   41
# MINISTERIO DE MINAS E ENERGIA - UNIDADES COM VÍNCULO DIRETO                                      40
# INST.BRAS.DO MEIO AMB.E DOS REC.NAT.RENOVAV.                                                     40
# INSTIT.NAC. DE METROLOG. QUALID. E TECNOLOGIA                                                    38
# MINISTERIO DO ESPORTE - UNIDADES COM VÍNCULO DIRETO                                              38
# MINISTERIO DA JUSTICA E SEGURANçA PUBLICA - UNIDADES COM VÍNCULO DIRETO                          37
# MINISTERIO DA CULTURA - UNIDADES COM VÍNCULO DIRETO                                              35
# MINISTERIO DO DESENVOLVIMENTO SOCIAL - UNIDADES COM VÍNCULO DIRETO                               34
# FUNDACAO ESCOLA NACIONAL DE ADM. PUBLICA                                                         33
# MINISTERIO DO TRABALHO E EMPREGO - UNIDADES COM VÍNCULO DIRETO                                   33
# FUND.COORD.DE APERF.DE PESSOAL NIVEL SUPERIOR                                                    32
# INSTITUTO NACIONAL DO SEGURO SOCIAL                                                              30
# AGENCIA NACIONAL DE SAUDE SUPLEMENTAR                                                            30
# MINIST. DO PLANEJAMENTO, DESENVOLV. E GESTAO - UNIDADES COM VÍNCULO DIRETO                       27
# COMISSAO DE VALORES MOBILIARIOS                                                                  25
# MINIST.DOS TRANSP.,PORTOS E AVIACAO CIVIL - UNIDADES COM VÍNCULO DIRETO                          25
# EMPRESA DE PESQUISA ENERGETICA                                                                   24
# ...                                                                                             ...
# UNIVERSIDADE FEDERAL FLUMINENSE                                                                   8
# ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCULO DIRETO                                            8
# INSTITUTO BRASILEIRO DE MUSEUS                                                                    7
# FUNDACAO NACIONAL DE ARTES                                                                        6
# SECRETARIA DE POLITICAS PARA AS MULHERES                                                          6
# INSTIT. NAC. DE COLONIZACAO E REFORMA AGRARIA                                                     6
# FUNDACAO UNIVERSIDADE DE BRASILIA                                                                 6
# EMPRESA BRASILEIRA DE SERVICOS HOSPITALARES                                                       6
# INSTITUTO BRASILEIRO DE TURISMO                                                                   5
# MINISTERIO DA TRANSPARENCIA E CGU - UNIDADES COM VÍNCULO DIRETO                                   5
# UNIVERSIDADE FEDERAL RURAL DO RIO DE JANEIRO                                                      4
# INSTITUTO NAC. DA PROPRIEDADE INDUSTRIAL                                                          4
# MINISTERIO DA INTEGRACAO NACIONAL - UNIDADES COM VÍNCULO DIRETO                                   4
# INST.FED.DE EDUC.,CIENC.E TEC.DO R.DE JANEIRO                                                     3
# FUNDACAO ALEXANDRE DE GUSMAO                                                                      3
# AGENCIA NACIONAL DE AGUAS                                                                         3
# CONSELHO ADMINISTRATIVO DE DEFESA ECONOMICA                                                       3
# FUNDACAO NACIONAL DE SAUDE                                                                        3
# AGENCIA NACIONAL DE TRANSPORTES AQUAVIARIOS                                                       3
# FUNDACAO BIBLIOTECA NACIONAL                                                                      2
# COLEGIO PEDRO II                                                                                  2
# CENTRO FED.EDUC.TECN.CELSO SUCKOW DA FONSECA                                                      2
# DEPARTAMENTO NACIONAL DE PRODUCAO MINERAL                                                         2
# FUNDACAO NACIONAL DO INDIO                                                                        2
# FUNDACAO CULTURAL PALMARES                                                                        2
# UNIVERSIDADE FEDERAL DE JUIZ DE FORA                                                              1
# CONSELHO NACIONAL DE DES.CIENT.E TECNOLOGICO                                                      1
# INST.FED.DE EDUC.,CIENC.E TEC.FLUMINENSE                                                          1
# SUPERINT. DE DESENVOLVIMENTO DO CENTRO-OESTE                                                      1
# AGENCIA ESPACIAL BRASILEIRA - AEB                                                                 1
#
# [81 rows x 1 columns]

# %% [markdown]
# ___
# __Material produzido para o curso__:
# * Introdução à Análise de Dados com Python
#
# __Autor__:
# * Fernando Sola Pereira
#
# __Revisão__:
# * 1.1
